# %% [markdown]
# # IMDB-5000 Dataset Analysis
#
# ### Objective: Given information about a movie, predict whether it is terrible, bad, good or great. This is a classification problem.
#
# ### Dataset
#
# The IMDB-5000 dataset is of size (5043,28), meaning we have 5043 observations (datapoints) and 28 features (variables). The variables are things like:
#
# * Director name
# * Duration
# * Names of top 3 actors in the movie
# * Language

# %% [markdown]
# ### Dataset Exploration
#
# We print the shape of the dataset to understand how many variables we are working with. We print the colums to see what each variable is.
#
# Since the 'score' is the dependent variable, it is useful to move this column to the end of the dataset.
#
# We need to know which columns contain `NaN` values as these need to be dealt with.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# read in the dataset, print shape and column titles
dataset = pd.read_csv('movie_metadata.csv')
print("Dataset shape: ", dataset.shape)
print("Dataset columns: ", dataset.columns)

# move the dependent variable to the end of the dataframe
scores = list(dataset.iloc[:, -3].values)
dataset = dataset.drop(columns='imdb_score')
dataset['scores'] = scores

# count number of NaN values in the columns
print("Columns with NaN values:")
nans = []
all_nans = dataset.isna().sum()

for i in range(len(all_nans)):
    nans.append(all_nans[i])

# plot the number of NaN values per column
plt.figure(dpi=150)
plt.bar(list(dataset.columns), nans)
plt.xticks([i for i in range(len(list(dataset.columns)))], list(dataset.columns), rotation='vertical')
plt.title('nan distribution')
plt.ylabel('no. of nans')

dataset = dataset.drop(columns='movie_imdb_link')
# we remove all rows where there is no score
dataset = dataset.dropna(axis=0,subset=['scores'])
print("new shape: ", dataset.shape)
# Out:
# Dataset shape:  (5043, 28)
# Dataset columns:  Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
# Columns with NaN values:
# new shape:  (5043, 27)

# %% [markdown]
# From this quick analysis we can see that gross has >10% of rows as NaN. We shall just remove this column instead of attempting to impute values.
#
# Some of these other columns can be reasonably imputed, such as budget and aspect ratio. For the former we can set NaNs to the average/median of the column and for aspect ratio we can set NaNs to the most frequent value of the column.

# %%
print("shape of data before: ", dataset.shape)

# Taking care of missing data
dataset = dataset.drop(columns='gross')

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer.fit(np.asarray(dataset['budget']).reshape(-1,1))
dataset['budget'] = imputer.transform(np.asarray(dataset['budget']).reshape(-1,1))

imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit(np.asarray(dataset['aspect_ratio']).reshape(-1,1))
dataset['aspect_ratio'] = imputer.transform(np.asarray(dataset['aspect_ratio']).reshape(-1,1))

nans = []
all_nans = dataset.isna().sum()

for i in range(len(all_nans)):
    nans.append(all_nans[i])

# plot the number of NaN values per column
plt.figure(dpi=150)
plt.bar(list(dataset.columns), nans)
plt.xticks([i for i in range(len(list(dataset.columns)))], list(dataset.columns), rotation='vertical')
plt.title('nan distribution')
plt.ylabel('no. of nans')

dataset = dataset.drop(columns=['color','plot_keywords','director_name','genres','movie_title','actor_1_name','actor_2_name','actor_3_name','language','country','content_rating'])

dataset = dataset.dropna(axis=0)
print("shape of data after: ", dataset.shape)
# Out:
# shape of data before:  (5043, 27)
# shape of data after:  (4857, 15)

# %%
# put the score columns into categories
scores = list(dataset['scores'])
dataset.drop(columns='scores')
score_classes = []

for score in scores:
    if score >= 1.6 and score < 4.0:
        score_classes.append("terrible")
    elif score >= 4.0 and score < 6.5:
        score_classes.append("ok")
    elif score >= 6.5 and score < 7.5:
        score_classes.append("good")
    elif score >= 7.5 and score < 10.0:
        score_classes.append("great")
        
dataset['scores'] = score_classes

from collections import Counter
scores = Counter(list(dataset['scores']))

# plot the number of NaN values per column
plt.figure(dpi=150)
plt.bar(scores.keys(), scores.values())
plt.xticks([i for i in range(len(list(scores.keys())))], list(scores.keys()),)
plt.title('score distribution')
plt.ylabel('no. of movies')
# Out:
# Text(0, 0.5, 'no. of movies')

# %%
from sklearn.feature_selection import VarianceThreshold

correlated_features = set()
correlation_matrix = dataset.corr()

for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.7:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
print(len(correlated_features))
print(correlated_features)

dataset.drop(labels=correlated_features, axis=1, inplace=True)
print(dataset.columns)
# Out:
# 2
# {'num_user_for_reviews', 'cast_total_facebook_likes'}
# Index(['num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'num_voted_users',
#        'facenumber_in_poster', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio', 'movie_facebook_likes',
#        'scores'],
#       dtype='object')

# %% [markdown]
# ### Now we split the dataset into the independent (X) and dependent variables (y)
#
# #### X is a matrix with 27 columns, y is a vector

# %%
print(dataset.columns)

X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# Encoding the Dependent Variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_le = le.fit_transform(y)
"""
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('cat', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
"""
"""
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
y = ohe.fit_transform(y.reshape(-1,1)).toarray()
print(X.shape)
print(y.shape)
"""
# Out:
# Index(['num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'num_voted_users',
#        'facenumber_in_poster', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio', 'movie_facebook_likes',
#        'scores'],
#       dtype='object')
# '\nfrom sklearn.preprocessing import OneHotEncoder\nohe = OneHotEncoder()\ny = ohe.fit_transform(y.reshape(-1,1)).toarray()\nprint(X.shape)\nprint(y.shape)\n'

# %%
# Feature Scaling (necessary for NNs)
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X = sc_X.fit_transform(X)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_le, test_size = 0.1, random_state = 0)

# %%
# Training the Naive Bayes model on the Training set
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
NB.fit(X_train, y_train)

y_pred = NB.predict(X_test)

a = accuracy_score(y_pred,y_test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 29.218106995884774

# %%
# Training the K-NN model on the Training set
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
KNN.fit(X_train, y_train)

y_pred = KNN.predict(X_test)

a = accuracy_score(y_pred,y_test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 56.79012345679012

# %%
# Training the Kernel SVM model on the Training set
from sklearn.svm import SVC
SVM = SVC(kernel = 'rbf', random_state = 0)
SVM.fit(X_train, y_train)

y_pred = SVM.predict(X_test)

from sklearn.metrics import accuracy_score
a = accuracy_score(y_pred,y_test)
print('Accuracy is:', a*100)
# Out:
# /Users/Ricardo/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Accuracy is: 61.111111111111114

# %%
# Training the Random Forest Classification model on the Training set
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators = 300, criterion = 'entropy', random_state = 0)
RFC.fit(X_train, y_train)

y_pred = RFC.predict(X_test)

a = accuracy_score(y_pred,y_test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 64.60905349794238

# %%
from sklearn.preprocessing import OneHotEncoder
print(y.shape)
ohe = OneHotEncoder()
y_ohe = ohe.fit_transform(y.reshape(-1,1)).toarray()
print(y_ohe.shape)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_ohe, test_size = 0.1, random_state = 0)
# Out:
# (4857,)
# (4857, 4)

# %%
# Create ANN
import keras
from keras.models import Sequential
from keras.layers import Dense

# initialise the ANN
Net = Sequential()

# Add input layer + first hidden layer
Net.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))

# Add second & third hidden layers
Net.add(Dense(units = 12, kernel_initializer = 'uniform', activation = 'relu'))
Net.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))

# Add the output layer
Net.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compile the Neural Network
Net.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# fit ANN to the training set
Net.fit(X_train, y_train, batch_size = 16, validation_data = (X_test,y_test), epochs = 100)
# Out:
# Train on 4371 samples, validate on 486 samples
# Epoch 1/100
# 4371/4371 [==============================] - 1s 174us/step - loss: 1.2075 - accuracy: 0.4322 - val_loss: 1.1495 - val_accuracy: 0.4342
# Epoch 2/100
# 4371/4371 [==============================] - 0s 65us/step - loss: 1.1038 - accuracy: 0.4338 - val_loss: 1.1356 - val_accuracy: 0.4342
# Epoch 3/100
# 4371/4371 [==============================] - 0s 65us/step - loss: 1.0888 - accuracy: 0.4390 - val_loss: 1.1209 - val_accuracy: 0.4506
# Epoch 4/100
# 4371/4371 [==============================] - 0s 68us/step - loss: 1.0737 - accuracy: 0.4722 - val_loss: 1.1068 - val_accuracy: 0.4979
# Epoch 5/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 1.0502 - accuracy: 0.5342 - val_loss: 1.0750 - val_accuracy: 0.5391
# Epoch 6/100
# 4371/4371 [==============================] - 0s 63us/step - loss: 1.0043 - accuracy: 0.5596 - val_loss: 1.0282 - val_accuracy: 0.5700
# Epoch 7/100
# 4371/4371 [==============================] - 0s 64us/step - loss: 0.9654 - accuracy: 0.5765 - val_loss: 1.0162 - val_accuracy: 0.5617
# Epoch 8/100
# 4371/4371 [==============================] - 0s 63us/step - loss: 0.9462 - accuracy: 0.5834 - val_loss: 0.9977 - val_accuracy: 0.6049
# Epoch 9/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 0.9325 - accuracy: 0.5857 - val_loss: 1.0013 - val_accuracy: 0.5761
# Epoch 10/100
# 4371/4371 [==============================] - 0s 69us/step - loss: 0.9213 - accuracy: 0.5914 - val_loss: 0.9807 - val_accuracy: 0.5988
# Epoch 11/100
# 4371/4371 [==============================] - 0s 80us/step - loss: 0.9114 - accuracy: 0.5978 - val_loss: 0.9772 - val_accuracy: 0.6008
# Epoch 12/100
# 4371/4371 [==============================] - 0s 70us/step - loss: 0.9035 - accuracy: 0.6040 - val_loss: 0.9781 - val_accuracy: 0.6111
# Epoch 13/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 0.9017 - accuracy: 0.6060 - val_loss: 0.9828 - val_accuracy: 0.5967
# Epoch 14/100
# 4371/4371 [==============================] - 0s 69us/step - loss: 0.8964 - accuracy: 0.6065 - val_loss: 0.9783 - val_accuracy: 0.5864
# Epoch 15/100
# 4371/4371 [==============================] - 0s 68us/step - loss: 0.8964 - accuracy: 0.6054 - val_loss: 0.9717 - val_accuracy: 0.5905
# Epoch 16/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 0.8948 - accuracy: 0.6051 - val_loss: 0.9659 - val_accuracy: 0.6049
# Epoch 17/100
# 4371/4371 [==============================] - 0s 63us/step - loss: 0.8930 - accuracy: 0.6099 - val_loss: 0.9766 - val_accuracy: 0.5885
# Epoch 18/100
# 4371/4371 [==============================] - 0s 72us/step - loss: 0.8895 - accuracy: 0.6134 - val_loss: 0.9785 - val_accuracy: 0.5988
# Epoch 19/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8895 - accuracy: 0.6115 - val_loss: 0.9641 - val_accuracy: 0.5823
# Epoch 20/100
# 4371/4371 [==============================] - 0s 64us/step - loss: 0.8868 - accuracy: 0.6113 - val_loss: 0.9721 - val_accuracy: 0.6008
# Epoch 21/100
# 4371/4371 [==============================] - 0s 64us/step - loss: 0.8876 - accuracy: 0.6143 - val_loss: 0.9495 - val_accuracy: 0.6029
# Epoch 22/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8854 - accuracy: 0.6152 - val_loss: 0.9546 - val_accuracy: 0.6235
# Epoch 23/100
# 4371/4371 [==============================] - 0s 71us/step - loss: 0.8851 - accuracy: 0.6175 - val_loss: 0.9483 - val_accuracy: 0.6152
# Epoch 24/100
# 4371/4371 [==============================] - 0s 72us/step - loss: 0.8842 - accuracy: 0.6134 - val_loss: 0.9493 - val_accuracy: 0.6132
# Epoch 25/100
# 4371/4371 [==============================] - 0s 74us/step - loss: 0.8820 - accuracy: 0.6140 - val_loss: 0.9544 - val_accuracy: 0.6029
# Epoch 26/100
# 4371/4371 [==============================] - 0s 71us/step - loss: 0.8814 - accuracy: 0.6138 - val_loss: 0.9514 - val_accuracy: 0.6091
# Epoch 27/100
# 4371/4371 [==============================] - 0s 65us/step - loss: 0.8827 - accuracy: 0.6175 - val_loss: 0.9461 - val_accuracy: 0.6029
# Epoch 28/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8813 - accuracy: 0.6115 - val_loss: 0.9480 - val_accuracy: 0.6008
# Epoch 29/100
# 4371/4371 [==============================] - 0s 68us/step - loss: 0.8821 - accuracy: 0.6120 - val_loss: 0.9518 - val_accuracy: 0.6091
# Epoch 30/100
# 4371/4371 [==============================] - 0s 72us/step - loss: 0.8803 - accuracy: 0.6152 - val_loss: 0.9515 - val_accuracy: 0.6070
# Epoch 31/100
# 4371/4371 [==============================] - 0s 70us/step - loss: 0.8799 - accuracy: 0.6143 - val_loss: 0.9417 - val_accuracy: 0.6193
# Epoch 32/100
# 4371/4371 [==============================] - 0s 65us/step - loss: 0.8794 - accuracy: 0.6150 - val_loss: 0.9439 - val_accuracy: 0.6111
# Epoch 33/100
# 4371/4371 [==============================] - 0s 68us/step - loss: 0.8802 - accuracy: 0.6150 - val_loss: 0.9410 - val_accuracy: 0.6132
# Epoch 34/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8762 - accuracy: 0.6138 - val_loss: 0.9458 - val_accuracy: 0.6008
# Epoch 35/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8784 - accuracy: 0.6134 - val_loss: 0.9407 - val_accuracy: 0.6235
# Epoch 36/100
# 4371/4371 [==============================] - 0s 69us/step - loss: 0.8771 - accuracy: 0.6131 - val_loss: 0.9463 - val_accuracy: 0.6152
# Epoch 37/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8759 - accuracy: 0.6163 - val_loss: 0.9509 - val_accuracy: 0.6070
# Epoch 38/100
# 4371/4371 [==============================] - 0s 63us/step - loss: 0.8747 - accuracy: 0.6193 - val_loss: 0.9476 - val_accuracy: 0.6132
# Epoch 39/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8764 - accuracy: 0.6182 - val_loss: 0.9456 - val_accuracy: 0.6091
# Epoch 40/100
# 4371/4371 [==============================] - 0s 62us/step - loss: 0.8748 - accuracy: 0.6168 - val_loss: 0.9492 - val_accuracy: 0.6132
# Epoch 41/100
# 4371/4371 [==============================] - 0s 64us/step - loss: 0.8735 - accuracy: 0.6227 - val_loss: 0.9452 - val_accuracy: 0.6008
# Epoch 42/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 0.8727 - accuracy: 0.6207 - val_loss: 0.9466 - val_accuracy: 0.6070
# Epoch 43/100
# 4371/4371 [==============================] - 0s 70us/step - loss: 0.8720 - accuracy: 0.6202 - val_loss: 0.9479 - val_accuracy: 0.6132
# Epoch 44/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8729 - accuracy: 0.6200 - val_loss: 0.9451 - val_accuracy: 0.6193
# Epoch 45/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8720 - accuracy: 0.6198 - val_loss: 0.9428 - val_accuracy: 0.6132
# Epoch 46/100
# 4371/4371 [==============================] - 0s 63us/step - loss: 0.8711 - accuracy: 0.6241 - val_loss: 0.9543 - val_accuracy: 0.6111
# Epoch 47/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8702 - accuracy: 0.6202 - val_loss: 0.9467 - val_accuracy: 0.6214
# Epoch 48/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8692 - accuracy: 0.6225 - val_loss: 0.9464 - val_accuracy: 0.6296
# Epoch 49/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8693 - accuracy: 0.6221 - val_loss: 0.9554 - val_accuracy: 0.6091
# Epoch 50/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8691 - accuracy: 0.6278 - val_loss: 0.9494 - val_accuracy: 0.6152
# Epoch 51/100
# 4371/4371 [==============================] - 0s 64us/step - loss: 0.8661 - accuracy: 0.6211 - val_loss: 0.9489 - val_accuracy: 0.6152
# Epoch 52/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8698 - accuracy: 0.6182 - val_loss: 0.9545 - val_accuracy: 0.6193
# Epoch 53/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8649 - accuracy: 0.6250 - val_loss: 0.9449 - val_accuracy: 0.6091
# Epoch 54/100
# 4371/4371 [==============================] - 0s 75us/step - loss: 0.8646 - accuracy: 0.6230 - val_loss: 0.9410 - val_accuracy: 0.6152
# Epoch 55/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 0.8643 - accuracy: 0.6234 - val_loss: 0.9321 - val_accuracy: 0.6152
# Epoch 56/100
# 4371/4371 [==============================] - 0s 69us/step - loss: 0.8618 - accuracy: 0.6239 - val_loss: 0.9482 - val_accuracy: 0.6152
# Epoch 57/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8630 - accuracy: 0.6177 - val_loss: 0.9373 - val_accuracy: 0.6235
# Epoch 58/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8601 - accuracy: 0.6225 - val_loss: 0.9420 - val_accuracy: 0.6173
# Epoch 59/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8622 - accuracy: 0.6198 - val_loss: 0.9401 - val_accuracy: 0.6152
# Epoch 60/100
# 4371/4371 [==============================] - 0s 64us/step - loss: 0.8598 - accuracy: 0.6200 - val_loss: 0.9300 - val_accuracy: 0.6152
# Epoch 61/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8583 - accuracy: 0.6239 - val_loss: 0.9248 - val_accuracy: 0.6091
# Epoch 62/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8563 - accuracy: 0.6289 - val_loss: 0.9256 - val_accuracy: 0.6091
# Epoch 63/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8584 - accuracy: 0.6239 - val_loss: 0.9171 - val_accuracy: 0.6358
# Epoch 64/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8562 - accuracy: 0.6271 - val_loss: 0.9070 - val_accuracy: 0.6193
# Epoch 65/100
# 4371/4371 [==============================] - 0s 73us/step - loss: 0.8535 - accuracy: 0.6230 - val_loss: 0.9128 - val_accuracy: 0.6111
# Epoch 66/100
# 4371/4371 [==============================] - 0s 73us/step - loss: 0.8503 - accuracy: 0.6266 - val_loss: 0.9019 - val_accuracy: 0.6276
# Epoch 67/100
# 4371/4371 [==============================] - 0s 65us/step - loss: 0.8495 - accuracy: 0.6237 - val_loss: 0.9025 - val_accuracy: 0.6235
# Epoch 68/100
# 4371/4371 [==============================] - 0s 66us/step - loss: 0.8488 - accuracy: 0.6237 - val_loss: 0.8922 - val_accuracy: 0.6235
# Epoch 69/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8454 - accuracy: 0.6264 - val_loss: 0.9025 - val_accuracy: 0.6173
# Epoch 70/100
# 4371/4371 [==============================] - 0s 67us/step - loss: 0.8442 - accuracy: 0.6273 - val_loss: 0.8931 - val_accuracy: 0.6276
# Epoch 71/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8431 - accuracy: 0.6255 - val_loss: 0.9036 - val_accuracy: 0.6255
# Epoch 72/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8422 - accuracy: 0.6296 - val_loss: 0.9084 - val_accuracy: 0.6255
# Epoch 73/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8426 - accuracy: 0.6287 - val_loss: 0.9044 - val_accuracy: 0.6235
# Epoch 74/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8420 - accuracy: 0.6214 - val_loss: 0.8961 - val_accuracy: 0.6193
# Epoch 75/100
# 4371/4371 [==============================] - 0s 62us/step - loss: 0.8434 - accuracy: 0.6241 - val_loss: 0.9053 - val_accuracy: 0.6152
# Epoch 76/100
# 4371/4371 [==============================] - 0s 62us/step - loss: 0.8414 - accuracy: 0.6307 - val_loss: 0.8899 - val_accuracy: 0.6276
# Epoch 77/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8402 - accuracy: 0.6296 - val_loss: 0.9069 - val_accuracy: 0.6235
# Epoch 78/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8389 - accuracy: 0.6353 - val_loss: 0.8968 - val_accuracy: 0.6276
# Epoch 79/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8401 - accuracy: 0.6262 - val_loss: 0.8827 - val_accuracy: 0.6214
# Epoch 80/100
# 4371/4371 [==============================] - 0s 61us/step - loss: 0.8399 - accuracy: 0.6255 - val_loss: 0.8978 - val_accuracy: 0.6399
# Epoch 81/100
# 4371/4371 [==============================] - 0s 62us/step - loss: 0.8391 - accuracy: 0.6303 - val_loss: 0.8944 - val_accuracy: 0.6193
# Epoch 82/100
# 4371/4371 [==============================] - 0s 60us/step - loss: 0.8385 - accuracy: 0.6317 - val_loss: 0.9094 - val_accuracy: 0.6296
# Epoch 83/100
# 4371/4371 [==============================] - 0s 62us/step - loss: 0.8390 - accuracy: 0.6291 - val_loss: 0.8973 - val_accuracy: 0.6214
# Epoch 84/100
# 4371/4371 [==============================] - 0s 87us/step - loss: 0.8385 - accuracy: 0.6298 - val_loss: 0.9009 - val_accuracy: 0.6173
# Epoch 85/100
# 4371/4371 [==============================] - 0s 86us/step - loss: 0.8373 - accuracy: 0.6253 - val_loss: 0.9142 - val_accuracy: 0.6255
# Epoch 86/100
# 4371/4371 [==============================] - 0s 83us/step - loss: 0.8373 - accuracy: 0.6262 - val_loss: 0.9167 - val_accuracy: 0.6235
# Epoch 87/100
# 4371/4371 [==============================] - 0s 84us/step - loss: 0.8385 - accuracy: 0.6278 - val_loss: 0.9093 - val_accuracy: 0.6214
# Epoch 88/100
# 4371/4371 [==============================] - 0s 77us/step - loss: 0.8371 - accuracy: 0.6296 - val_loss: 0.9078 - val_accuracy: 0.6337
# Epoch 89/100
# 4371/4371 [==============================] - 0s 84us/step - loss: 0.8370 - accuracy: 0.6264 - val_loss: 0.9082 - val_accuracy: 0.6337
# Epoch 90/100
# 4371/4371 [==============================] - 0s 81us/step - loss: 0.8348 - accuracy: 0.6246 - val_loss: 0.9062 - val_accuracy: 0.6152
# Epoch 91/100
# 4371/4371 [==============================] - 0s 81us/step - loss: 0.8355 - accuracy: 0.6296 - val_loss: 0.9087 - val_accuracy: 0.6214
# Epoch 92/100
# 4371/4371 [==============================] - 0s 79us/step - loss: 0.8353 - accuracy: 0.6323 - val_loss: 0.9051 - val_accuracy: 0.6276
# Epoch 93/100
# 4371/4371 [==============================] - 0s 81us/step - loss: 0.8341 - accuracy: 0.6303 - val_loss: 0.9067 - val_accuracy: 0.6255
# Epoch 94/100
# 4371/4371 [==============================] - 0s 86us/step - loss: 0.8330 - accuracy: 0.6298 - val_loss: 0.9085 - val_accuracy: 0.6214
# Epoch 95/100
# 4371/4371 [==============================] - 0s 86us/step - loss: 0.8334 - accuracy: 0.6289 - val_loss: 0.9115 - val_accuracy: 0.6296
# Epoch 96/100
# 4371/4371 [==============================] - 0s 84us/step - loss: 0.8344 - accuracy: 0.6273 - val_loss: nan - val_accuracy: 0.6214
# Epoch 97/100
# 4371/4371 [==============================] - 0s 83us/step - loss: 0.8340 - accuracy: 0.6356 - val_loss: nan - val_accuracy: 0.6132
# Epoch 98/100
# 4371/4371 [==============================] - 0s 88us/step - loss: 0.8338 - accuracy: 0.6344 - val_loss: 0.9137 - val_accuracy: 0.6091
# Epoch 99/100
# 4371/4371 [==============================] - 0s 88us/step - loss: 0.8324 - accuracy: 0.6333 - val_loss: 0.9076 - val_accuracy: 0.6152
# Epoch 100/100
# 4371/4371 [==============================] - 0s 86us/step - loss: 0.8320 - accuracy: 0.6369 - val_loss: 0.9044 - val_accuracy: 0.6337

# %%
y_pred = classifier.predict(X_test)

# Converting predictions to label
pred_classes = list()
for i in range(len(y_pred)):
    pred_classes.append(np.argmax(y_pred[i]))

# Converting one hot encoded test label to label
test_classes = list()
for i in range(len(y_test)):
    test_classes.append(np.argmax(y_test[i]))

from sklearn.metrics import accuracy_score
a = accuracy_score(pred_classes,test_classes)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 58.0246913580247
